# %%
import numpy as np

v = np.array([[-0.43425751, -0.89039464, -0.72752934], [-0.62632540, 0.45516156, -0.28974870], [-0.64740783, -0.00503438, 0.62188966]])
w = np.array([1.40323964, -0.04086520, 0.36762557])

print(v@np.diag(w)@np.linalg.inv(v))
# Out:
# [[0.27       0.61       0.17      ]
#  [0.34       0.63       0.52      ]
#  [0.22       0.44       0.83000001]]

# %%
import numpy as np

A = np.array([[0.81, 0.71, 0.17, 0.17, 0.78, 0.79, 0.82, 0.08], [0.58, 0.27, 0.69, 0.98, 0.51, 0.10, 0.67, 0.99], [0.43, 0.50, 0.72, 0.43, 0.70, 0.53, 0.38, 0.71], [0.23, 0.59, 0.46, 0.80, 0.98, 0.28, 0.39, 0.54], [0.34, 0.74, 0.77, 0.90, 0.92, 0.79, 0.30, 0.19], [0.45, 0.12, 0.53, 0.08, 0.50, 0.40, 0.87, 0.06], [0.67, 0.72, 0.99, 0.32, 0.83, 0.68, 0.93, 0.71], [0.63, 0.92, 0.93, 0.95, 0.23, 0.38, 0.66, 0.53]])
w, v = np.linalg.eig(A)
print(w)
print()
print(v)
print()
print(v[:,0])
# Out:
# [ 4.63380005  1.02145906  0.62560479 -0.65841028 -0.47785727  0.2814287
#   0.08973546 -0.1357605 ]
#
# [[ 0.32376686  0.5658612  -0.40916916 -0.03405774 -0.23163146  0.78091531
#   -0.70211687 -0.41407446]
#  [ 0.3744337  -0.24525037  0.33069533  0.39436551  0.05588997 -0.0850644
#    0.04523539 -0.0569488 ]
#  [ 0.33016146 -0.02611933  0.12362336  0.35642089 -0.46364319 -0.08484324
#   -0.17933855 -0.37996832]
#  [ 0.3264687  -0.4923929  -0.20209766  0.22855901 -0.23832984  0.04346081
#    0.08735182  0.14127469]
#  [ 0.3576368  -0.26515855 -0.52289631 -0.36135273  0.12388708  0.26018533
#   -0.25526258 -0.27400434]
#  [ 0.23220003  0.45694285 -0.0859734  -0.11668715  0.45558534 -0.20238719
#    0.37589859  0.65870366]
#  [ 0.44677419  0.2892162   0.35220331  0.12369259 -0.15929766 -0.44906449
#    0.45512684  0.16808871]
#  [ 0.39743919 -0.1173394   0.51208968 -0.71031634  0.65051925 -0.25205596
#    0.22714276  0.35176981]]
#
# ...
